# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.extraction import write_channel_csvs, parse_folder_to_channel_dfs

# %%
ROOT_FOLDER_OLDER_ADULTS = 'older_adults'
for subject_id in range(1, 8):
    write_channel_csvs(
        parse_folder_to_channel_dfs(
            f'./{ROOT_FOLDER_OLDER_ADULTS}/original_files/physiological_signal/00{subject_id}-3YK9K1J2D2/raw_data/v6'
            ), 
        out_dir=f'./{ROOT_FOLDER_OLDER_ADULTS}/extraction_from_original_files/00{subject_id}', 
        prefix=f'00{subject_id}')
# Out:
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/001/001_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/001/001_eda.csv (7328 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/001/001_temperature.csv (1832 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/001/001_bvp.csv (117120 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/001/001_systolicPeaks.csv (2119 rows)
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/002/002_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/002/002_eda.csv (7052 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/002/002_temperature.csv (1763 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/002/002_bvp.csv (110528 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/002/002_systolicPeaks.csv (2404 rows)
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/003/003_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/003/003_eda.csv (8608 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/003/003_temperature.csv (2152 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/003/003_bvp.csv (137152 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/003/003_systolicPeaks.csv (2553 rows)
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/004/004_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/004/004_eda.csv (12684 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/004/004_temperature.csv (3171 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/004/004_bvp.csv (202688 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/004/004_systolicPeaks.csv (4370 rows)
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/005/005_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/005/005_eda.csv (5996 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/005/005_temperature.csv (1499 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/005/005_bvp.csv (95872 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/005/005_systolicPeaks.csv (1857 rows)
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/006/006_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/006/006_eda.csv (5900 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/006/006_temperature.csv (1475 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/006/006_bvp.csv (94080 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/006/006_systolicPeaks.csv (1736 rows)
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./older_adults/extraction_from_original_files/007/007_accelerometer.csv (0 rows)
# [OK] wrote eda: ./older_adults/extraction_from_original_files/007/007_eda.csv (13300 rows)
# [OK] wrote temperature: ./older_adults/extraction_from_original_files/007/007_temperature.csv (3324 rows)
# [OK] wrote bvp: ./older_adults/extraction_from_original_files/007/007_bvp.csv (212544 rows)
# [OK] wrote systolicPeaks: ./older_adults/extraction_from_original_files/007/007_systolicPeaks.csv (4221 rows)

# %%
from src.preprocessing import MergeConfig, process_all_subjects, SCIPY_OK

cfg = MergeConfig(
    # all are default parameter values; explicitly specified here for readability
    #   for a complete list of default configurations, see the definition of class `MergeConfig`
    gap_threshold_s=3.0,
    map_method="snap",
    map_snap_kind = "one_to_one",   # "one_to_one" or "per_grid"
    map_interp_kind="linear",
    # band pass filter frequency of inferred heart rate (HR)
    hr_bp_low_hz=0,
    hr_bp_high_hz=4,
    # interpolation parameters of HR
    hr_target="1hz",
    hr_interp_kind="cubic",
)


if (cfg.map_method == "interp" or cfg.hr_interp_kind in ("quadratic", "cubic")) and not SCIPY_OK:
    print("[WARN] SciPy not available: quadratic/cubic will fall back to linear; bandpass disabled.")

process_all_subjects(
    f'./{ROOT_FOLDER_OLDER_ADULTS}/extraction_from_original_files', 
    f'./{ROOT_FOLDER_OLDER_ADULTS}/processed_data/per_subject', 
    cfg)
# Out:
# [SUBJECT 001] -> ./older_adults/processed_data/per_subject/001_merged_64hz.csv
# [SUBJECT 002] -> ./older_adults/processed_data/per_subject/002_merged_64hz.csv
# [SUBJECT 003] -> ./older_adults/processed_data/per_subject/003_merged_64hz.csv
# [SUBJECT 004] -> ./older_adults/processed_data/per_subject/004_merged_64hz.csv
# [SUBJECT 005] -> ./older_adults/processed_data/per_subject/005_merged_64hz.csv
# [SUBJECT 006] -> ./older_adults/processed_data/per_subject/006_merged_64hz.csv
# [SUBJECT 007] -> ./older_adults/processed_data/per_subject/007_merged_64hz.csv

# %%
from src.merge import batch_join

batch_join(
    f"./{ROOT_FOLDER_OLDER_ADULTS}/processed_data/per_subject", 
    f"./{ROOT_FOLDER_OLDER_ADULTS}/original_files/self_report", 
    f"./{ROOT_FOLDER_OLDER_ADULTS}/processed_data/with_self_report",
    time_window_csv=f'./{ROOT_FOLDER_OLDER_ADULTS}/experiment_time.csv',
    merged_glob = "*_merged_*hz.csv",)
# Out:
# [OK] 001: ./older_adults/processed_data/per_subject/001_merged_64hz.csv + ./older_adults/original_files/self_report/001.csv -> ./older_adults/processed_data/with_self_report/001_merged_64hz_with_self_report.csv
# [OK] 002: ./older_adults/processed_data/per_subject/002_merged_64hz.csv + ./older_adults/original_files/self_report/002.csv -> ./older_adults/processed_data/with_self_report/002_merged_64hz_with_self_report.csv
# [OK] 003: ./older_adults/processed_data/per_subject/003_merged_64hz.csv + ./older_adults/original_files/self_report/003.csv -> ./older_adults/processed_data/with_self_report/003_merged_64hz_with_self_report.csv
# [OK] 004: ./older_adults/processed_data/per_subject/004_merged_64hz.csv + ./older_adults/original_files/self_report/004.csv -> ./older_adults/processed_data/with_self_report/004_merged_64hz_with_self_report.csv
# [OK] 005: ./older_adults/processed_data/per_subject/005_merged_64hz.csv + ./older_adults/original_files/self_report/005.csv -> ./older_adults/processed_data/with_self_report/005_merged_64hz_with_self_report.csv
# [OK] 006: ./older_adults/processed_data/per_subject/006_merged_64hz.csv + ./older_adults/original_files/self_report/006.csv -> ./older_adults/processed_data/with_self_report/006_merged_64hz_with_self_report.csv
# [OK] 007: ./older_adults/processed_data/per_subject/007_merged_64hz.csv + ./older_adults/original_files/self_report/007.csv -> ./older_adults/processed_data/with_self_report/007_merged_64hz_with_self_report.csv
