# %% [markdown]
# # Process older-adult cohort (Empatica EmbracePlus)
#
# This notebook converts the **older-adult** cohort’s raw Empatica **EmbracePlus** data file (.avro files) into:
#
# 1) **Per-subject physiological time series** aligned onto a BVP-native **64 Hz** time grid
# 2) The same time series with **self-report pain labels** snapped to the nearest physiological timestamp
# 3) A single **combined** file across all older-adult subjects (`older_adults.feather` and `older_adults.csv`)
#
# ---
#
# ## What this notebook does
#
# - **Extract** EmbracePlus raw files into per-channel CSVs (BVP / EDA / temperature / systolic peaks)
# - **Merge** channels onto a single timeline (BVP defines the unified standard 64-Hz grid)
# - **Optionally stitch** short gaps between segments into continuous “sections”
# - **Join** self-report pain ratings onto the physiological grid by nearest timestamp
# - **Export** per-subject files and a combined cohort-level dataset
#
# ---
#
# ## Glossary (plain language)
#
# - **BVP (blood volume pulse)**: a PPG-like waveform from the wrist; used here as the “master clock” at 64 Hz
# - **EDA (electrodermal activity)**: skin conductance (sweat response proxy), usually lower frequency than BVP
# - **Skin temperature**: wrist temperature channel
# - **Systolic peaks**: timestamps of detected pulse peaks; used to derive HR/IBI
# - **Segment**: a continuous chunk in the raw export (devices often split recordings)
# - **Section**: multiple segments treated as one continuous block when gaps are small
# - **Snap vs interpolate**:
#   - **Snap**: copy the nearest sample (robust, preserves original values)
#   - **Interpolate**: estimate values between samples (smoother, but more assumptions)
#
# ---
#
# ## Expected folder layout (older cohort)
#
# This notebook assumes you have a `data/older_adults/` folder with an `original_files/` subfolder.
#
# Folder structure (simply download the dataset and paste the root `data` folder under the same directory as this file):
# ```
# data/
#   older_adults/
#     original_files/
#       physiological_signal/
#         001-<device-and-session-id>/raw_data/v6/...
#         002-<device-and-session-id>/raw_data/v6/...
#     self_report/
#       001.csv
#       002.csv
#       ...
#     experiment_time.csv
#     extraction_from_original_files/
#     processed_data/
#       combined/
#       with_self_report/
# ```
#
# ---
#
# ## Outputs
#
# - `.../processed_data/combined/<subject>_merged_64hz.csv`
#   - Columns typically include: `timestamp_ns`, `datetime_utc`, `segment`, `section`, `bvp`, `eda`, `temperature`, `hr`
# - `.../processed_data/with_self_report/<subject>_merged_64hz_with_self_report.csv`
#   - Adds: `PainLevel` (and `Trial` if desired)
# - `older_adults.feather`, `older_adults.csv` at `data/older_adults/`
#
# **Timestamps:** `timestamp_ns` is epoch nanoseconds in **UTC**. `datetime_utc` is a readable UTC datetime.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# import OS file system functions
import os
import glob
from pathlib import Path

# Define folder names
ROOT_DATA_FOLDER = "./data"
ROOT_FOLDER_OLDER_ADULTS = os.path.join(ROOT_DATA_FOLDER, "older_adults")
ROOT_ORIGINAL = os.path.join(ROOT_FOLDER_OLDER_ADULTS, "original_files")

SELF_REPORT_FOLDER = os.path.join(ROOT_ORIGINAL, "self_report")
PHYSIO_ROOT = os.path.join(ROOT_ORIGINAL, "physiological_signal")

EXTRACTION_OUTPUT_DIR = os.path.join(ROOT_FOLDER_OLDER_ADULTS, "extraction_from_original_files")
PROCESSED_DATA_OUTPUT_DIR = os.path.join(ROOT_FOLDER_OLDER_ADULTS, "processed_data")

# Ensure expected output dirs exist
os.makedirs(EXTRACTION_OUTPUT_DIR, exist_ok=True)
os.makedirs(PROCESSED_DATA_OUTPUT_DIR, exist_ok=True)

def find_embraceplus_v6_dir(physio_root: str, subject_id: str) -> str:
    """
    Locate EmbracePlus export folder for a subject.

    The repo originally used a hard-coded folder name like:
      physiological_signal/00{subject_id}-3YK9K1J2D2/raw_data/v6

    For publishing, we auto-detect:
      physiological_signal/<subject_id>-*/raw_data/v6
    """
    pattern = os.path.join(physio_root, f"{subject_id}-*", "raw_data", "v6")
    hits = sorted(glob.glob(pattern))
    if not hits:
        raise FileNotFoundError(f"Could not find EmbracePlus v6 folder for {subject_id}: {pattern}")
    if len(hits) > 1:
        print(f"[WARN] Multiple matches for {subject_id}; using: {hits[0]}")
    return hits[0]

# %% [markdown]
# ## Step 1 — Extract EmbracePlus raw data into per-channel CSVs
#
# EmbracePlus raw data may contain multiple channels and multiple segments.
# This step converts each subject’s raw data folder into separate CSV files per channel, saved under:
#
# `data/older_adults/extraction_from_original_files/<subject>/`
#
# This “extraction” step is intentionally separate from the merging step for better readability and modularity.

# %% [markdown]
# Note: for the cell below, you can update the `subjects` list if you add/remove subjects

# %%
# import local functions
from silver_pain.extraction import write_channel_csvs, parse_folder_to_channel_dfs

subjects = [f"{i:03d}" for i in range(1, 8)]  # 001..007

for sid in subjects:
    raw_v6_dir = find_embraceplus_v6_dir(PHYSIO_ROOT, sid)
    out_dir = os.path.join(EXTRACTION_OUTPUT_DIR, sid)

    print(f"[SUBJECT {sid}] raw={raw_v6_dir}")
    channel_dfs = parse_folder_to_channel_dfs(raw_v6_dir)
    write_channel_csvs(channel_dfs, out_dir=out_dir, prefix=sid)
# Out:
# [SUBJECT 001] raw=./data/older_adults/original_files/physiological_signal/001-3YK9K1J2D2/raw_data/v6
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./data/older_adults/extraction_from_original_files/001/001_accelerometer.csv (0 rows)
# [OK] wrote eda: ./data/older_adults/extraction_from_original_files/001/001_eda.csv (7328 rows)
# [OK] wrote temperature: ./data/older_adults/extraction_from_original_files/001/001_temperature.csv (1832 rows)
# [OK] wrote bvp: ./data/older_adults/extraction_from_original_files/001/001_bvp.csv (117120 rows)
# [OK] wrote systolicPeaks: ./data/older_adults/extraction_from_original_files/001/001_systolicPeaks.csv (2119 rows)
# [SUBJECT 002] raw=./data/older_adults/original_files/physiological_signal/002-3YK9K1J2D2/raw_data/v6
# [WARN] No data for accelerometer
# [OK] wrote accelerometer: ./data/older_adults/extraction_from_original_files/002/002_accelerometer.csv (0 rows)
# ...

# %% [markdown]
# ## Step 2 — Merge channels onto a BVP-native 64 Hz grid
#
# We build a **64 Hz time grid** using the BVP timestamps (“BVP-native grid”), then map other channels onto it.
#
# Key options:
# - `map_method="snap"`: robust; copies nearest EDA/TEMP sample onto each grid time
# - `map_method="interp"`: smoother; estimates intermediate values (requires SciPy for quadratic/cubic)
# - HR is derived from **systolic peaks**, smoothed and preprocessed (see `src/silver_pain/preprocessing.py` for details), and then mapped onto the same grid.
#
# **Sections:** If consecutive segments have small gaps (default ≤ 3 seconds), they are treated as the same continuous “section”. You can change this behavior if you desire more faithful (or more interpolated) data.

# %%
from silver_pain.preprocessing import MergeConfig, process_all_subjects, SCIPY_OK

cfg = MergeConfig(
    # all are default parameter values; explicitly specified here for readability
    #   for a complete list of default configurations, see the definition of class `MergeConfig`
    gap_threshold_s=3.0,
    map_method="snap",
    map_snap_kind = "one_to_one",   # "one_to_one" or "per_grid"
    map_interp_kind="linear",
    # band pass filter frequency of inferred heart rate (HR)
    hr_bp_low_hz=0,
    hr_bp_high_hz=4,
    # interpolation parameters of HR
    hr_target="1hz",
    hr_interp_kind="cubic",
)

# You may also import the default config from config/preprocessing.py
#   uncomment the following code block to try

""" from config.preprocessing import default_merge_config_older_adults
cfg = default_merge_config_older_adults """


if (cfg.map_method == "interp" or cfg.hr_interp_kind in ("quadratic", "cubic")) and not SCIPY_OK:
    print("[WARN] SciPy not available: quadratic/cubic will fall back to linear; bandpass disabled.")

os.makedirs(os.path.join(PROCESSED_DATA_OUTPUT_DIR, "combined"), exist_ok=True)
# merge extracted signals
process_all_subjects(
    root=EXTRACTION_OUTPUT_DIR, 
    combined_out_dir=os.path.join(PROCESSED_DATA_OUTPUT_DIR, "combined"), 
    cfg=cfg)
# Out:
# [SUBJECT 001] -> ./data/older_adults/processed_data/combined/001_merged_64hz.csv
# [SUBJECT 002] -> ./data/older_adults/processed_data/combined/002_merged_64hz.csv
# [SUBJECT 003] -> ./data/older_adults/processed_data/combined/003_merged_64hz.csv
# [SUBJECT 004] -> ./data/older_adults/processed_data/combined/004_merged_64hz.csv
# [SUBJECT 005] -> ./data/older_adults/processed_data/combined/005_merged_64hz.csv
# [SUBJECT 006] -> ./data/older_adults/processed_data/combined/006_merged_64hz.csv
# [SUBJECT 007] -> ./data/older_adults/processed_data/combined/007_merged_64hz.csv

# %% [markdown]
# ## Step 3 — Join self-report pain ratings onto the physiological grid
#
# Self-report files are joined by **nearest timestamp** (“snap to grid”).
#
# Optional: You may use our provided `experiment_time.csv` to filter data to only the experiment window(s).
# This is useful because the raw device data files include pre/post recording outside the protocol.

# %%
from silver_pain.merge import batch_join

os.makedirs(os.path.join(PROCESSED_DATA_OUTPUT_DIR, "with_self_report"), exist_ok=True)

batch_join(
    merged_dir=os.path.join(PROCESSED_DATA_OUTPUT_DIR, "combined"), 
    self_report_dir=SELF_REPORT_FOLDER, 
    out_dir=os.path.join(PROCESSED_DATA_OUTPUT_DIR, "with_self_report"),
    time_window_csv=os.path.join(ROOT_FOLDER_OLDER_ADULTS, 'experiment_time.csv'),
    merged_glob = "*_merged_*hz.csv",  
    max_snap_s=cfg.pain_max_snap_s,  # tolerance in seconds; set to None to always snap
)
# Out:
# [OK] 001: ./data/older_adults/processed_data/combined/001_merged_64hz.csv + ./data/older_adults/original_files/self_report/001.csv -> ./data/older_adults/processed_data/with_self_report/001_merged_64hz_with_self_report.csv
# [OK] 002: ./data/older_adults/processed_data/combined/002_merged_64hz.csv + ./data/older_adults/original_files/self_report/002.csv -> ./data/older_adults/processed_data/with_self_report/002_merged_64hz_with_self_report.csv
# [OK] 003: ./data/older_adults/processed_data/combined/003_merged_64hz.csv + ./data/older_adults/original_files/self_report/003.csv -> ./data/older_adults/processed_data/with_self_report/003_merged_64hz_with_self_report.csv
# [OK] 004: ./data/older_adults/processed_data/combined/004_merged_64hz.csv + ./data/older_adults/original_files/self_report/004.csv -> ./data/older_adults/processed_data/with_self_report/004_merged_64hz_with_self_report.csv
# ...

# %% [markdown]
# ## Step 4 — Export a single cohort-level table
#
# This final step concatenates all per-subject `with_self_report/*.csv` files into:
# - `older_adults.feather` (fast load; requires `pyarrow`)
# - `older_adults.csv` (universal)
#
# If you run into memory issues on very large datasets, load/write in chunks.

# %%
import os
import pandas as pd
from pathlib import Path

directory_path = Path(os.path.join(ROOT_FOLDER_OLDER_ADULTS, "processed_data", "with_self_report"))
paths = sorted(directory_path.glob("*.csv"))

if not paths:
    raise FileNotFoundError(f"No CSV files found in: {directory_path}")

# iterate through folder to conjoin all subjects' data
df_all = []
for file_path in paths:
    print(file_path)
    subject_df = pd.read_csv(file_path)
    subject_id = file_path.name.split("_")[0]
    subject_df["subject"] = subject_id
    df_all.append(subject_df)
# combine all dataframe
df = pd.concat(df_all, ignore_index=True)
# write to files
df.to_feather(os.path.join(ROOT_FOLDER_OLDER_ADULTS, "older_adults.feather"))
df.to_csv(os.path.join(ROOT_FOLDER_OLDER_ADULTS, "older_adults.csv"), index=False)
# message
print(f"[OK] Wrote combined cohort files with {len(df):,} rows.")
# Out:
# data/older_adults/processed_data/with_self_report/001_merged_64hz_with_self_report.csv
# data/older_adults/processed_data/with_self_report/002_merged_64hz_with_self_report.csv
# data/older_adults/processed_data/with_self_report/003_merged_64hz_with_self_report.csv
# data/older_adults/processed_data/with_self_report/004_merged_64hz_with_self_report.csv
# data/older_adults/processed_data/with_self_report/005_merged_64hz_with_self_report.csv
# data/older_adults/processed_data/with_self_report/006_merged_64hz_with_self_report.csv
# data/older_adults/processed_data/with_self_report/007_merged_64hz_with_self_report.csv
# [OK] Wrote combined cohort files with 554,400 rows.
